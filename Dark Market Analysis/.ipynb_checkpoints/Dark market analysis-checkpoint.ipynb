# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
post_data = pd.read_csv('posts.csv')
seller_data = pd.read_csv('sellers.csv')
seller_data
# Out:
#                 Seller  Number of reviews grade (out of 5)  Active listing  \
# 0            woodstock               34.0             4,27            85.0
# 1          donalddrugs              340.0             4,97           151.0
# 2          qualityshop               51.0             4,34            86.0
# 3            firebunny              484.0             4,73            64.0
# 4          amphetamine                NaN              NaN             NaN
# 5          roiducannab               39.0             4,75            47.0
# 6          thehammockc                NaN              NaN             NaN
# 7          tomandjerry                NaN              NaN             NaN
# 8          montecrypto                NaN              NaN             NaN
# 9       straightfromnl                NaN              NaN             NaN
# 10            marynaga               62.0             4,55           548.0
# 11             eternos                NaN              NaN             NaN
# 12         centralbank                NaN              NaN             NaN
# 13        boyfootstep1                NaN              NaN             NaN
# 14         probitexcha                NaN              NaN             NaN
# 15         namedecline                NaN              NaN             NaN
# 16               kenza                NaN              NaN             NaN
# 17           sexyhomer                NaN              NaN             NaN
# 18                 NaN                NaN              NaN             NaN
# 19                 NaN                NaN              NaN             NaN
# 20                 NaN                NaN              NaN             NaN
# 21                 NaN                NaN              NaN             NaN
# 22                 NaN                NaN              NaN             NaN
# 23                 NaN                NaN              NaN             NaN
# 24           goldapple                NaN              NaN             NaN
# 25            drhack3r                NaN              NaN             NaN
# 26                 NaN                NaN              NaN             NaN
# 27  thedangeroustomato                NaN              NaN             NaN
#
#    Kind of vendor
# 0         Diamond
# 1           Basic
# 2            Gold
# 3           Basic
# 4             NaN
# 5           Basic
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10          Basic
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 23            NaN
# 24            NaN
# 25            NaN
# 26            NaN
# 27            NaN

# %%
post_data['Class'].value_counts().plot(kind='bar', color=['red', 'green', 'blue', 'black', 'cyan', 'orange'])
plt.xlabel('Class', labelpad=14)
plt.ylabel('Count', labelpad=14)
plt.title('Count of post classes', y=1.02)
# Out:
# Text(0.5, 1.02, 'Count of post classes')

# %%
post_data['Category'].value_counts().plot(kind='bar', color=['red', 'green', 'blue', 'black', 'yellow', 'cyan', 'purple', 'orange', 'pink'])
plt.xlabel('Category', labelpad=14)
plt.ylabel('Count', labelpad=14)
plt.title('Count of post categories', y=1.02)
# Out:
# Text(0.5, 1.02, 'Count of post categories')
